# %%
import matplotlib.pyplot as plt

data = {
    "train_losses": [
        1.4941563800509488,
        1.291609472196017,
        0.9293379094451666,
        0.5246032721008218,
        0.324703585422997
    ],
    "val_losses": [
        5.585135712510064,
        4.4684137403965,
        2.514046902457873,
        1.2736861145212537,
        0.8076853517975126
    ],
    "train_intent_acc": [
        0.06349723217193097,
        0.1747685723589338,
        0.4296413453039959,
        0.7094013118109503,
        0.8375587291249942
    ],
    "train_category_f1": [
        0.12483467256518567,
        0.2994935697173128,
        0.665361252950858,
        0.8934697705964442,
        0.9578347683226567
    ],
    "train_ner_micro_f1": [
        0.0012641425952847481,
        0.0005923293351103214,
        0.06552345365983853,
        0.21095312152854923,
        0.29234828496042214
    ],
    "val_intent_acc": [
        0.14774841831038332,
        0.43096390026051357,
        0.7245999255675475,
        0.8589505024190547,
        0.9188686267212505
    ],
    "val_category_f1": [
        0.18705732595294014,
        0.546455189400812,
        0.8479026969354531,
        0.9504953012891245,
        0.9789654963817446
    ],
    "val_ner_macro_f1": [
        0.0,
        0.0,
        0.06790557164215826,
        0.08784576694706805,
        0.1096744447267427
    ],
    "epoch_times": [
        295.27840065956116,
        307.2279989719391,
        307.10392332077026,
        309.39295959472656,
        309.55501413345337
    ]
}

epochs = list(range(1, 6))

# Plot Train and Validation Losses
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.plot(epochs, data["train_losses"], label='Train Loss')
plt.plot(epochs, data["val_losses"], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Validation Losses')
plt.legend()

# Plot Train and Validation Intent Accuracy
plt.subplot(2, 2, 2)
plt.plot(epochs, data["train_intent_acc"], label='Train Intent Accuracy')
plt.plot(epochs, data["val_intent_acc"], label='Validation Intent Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train and Validation Intent Accuracy')
plt.legend()

# Plot Train and Validation Category F1 Score
plt.subplot(2, 2, 3)
plt.plot(epochs, data["train_category_f1"], label='Train Category F1')
plt.plot(epochs, data["val_category_f1"], label='Validation Category F1')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('Train and Validation Category F1 Score')
plt.legend()

# Plot Train NER Micro F1 and Validation NER Macro F1
plt.subplot(2, 2, 4)
plt.plot(epochs, data["train_ner_micro_f1"], label='Train NER Micro F1')
plt.plot(epochs, data["val_ner_macro_f1"], label='Validation NER Macro F1')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('Train NER Micro F1 and Validation NER Macro F1')
plt.legend()

plt.tight_layout()
plt.show()
